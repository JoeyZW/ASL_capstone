# %%
import os
import shutil

import pandas as pd
import tensorflow as tf
import numpy as np
import tensorflow_hub as hub
# import tensorflow_text as text
import keras

from keras import Input
from keras.layers import TextVectorization
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import (
    GRU,
    Conv1D,
    Dense,
    Embedding,
    Flatten,
    Lambda,
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical

print(tf.__version__)
# Out:
# 2023-02-15 18:40:38.446967: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-15 18:40:39.342726: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2023-02-15 18:40:39.342824: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2023-02-15 18:40:39.342836: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2.11.0

# %%
embed = hub.KerasLayer("https://tfhub.dev/google/universal-sentence-encoder/4")
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# 2023-02-15 18:40:40.327688: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:40:40.340176: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:40:40.341930: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:40:40.344116: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-15 18:40:40.344982: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:40:40.346714: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:40:40.348365: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:40:41.109650: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:40:41.111744: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:40:41.113482: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:40:41.115216: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12963 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %%
#read data
data = pd.read_csv("../data/patent_rand100k.csv")
#shuffle data
# data = data.sample(frac=1)

# %%
# # data.groupby('ipc_section').count()
# dataSort = data.query('(ipc_section == "A")').sample(n=1000)
# dataSort = pd.concat([dataSort,data.query('(ipc_section == "B")').sample(n=1000)])
# dataSort = pd.concat([dataSort,data.query('(ipc_section == "C")').sample(n=1000)])
# dataSort = pd.concat([dataSort,data.query('(ipc_section == "D")').sample(n=1000)])
# dataSort = pd.concat([dataSort,data.query('(ipc_section == "E")').sample(n=1000)])
# dataSort = pd.concat([dataSort,data.query('(ipc_section == "F")').sample(n=1000)])
# dataSort = pd.concat([dataSort,data.query('(ipc_section == "G")').sample(n=1000)])
# dataSort = pd.concat([dataSort,data.query('(ipc_section == "H")').sample(n=1000)])
# # data=data.sample(50000)
# # data=dataSort

# %%
len(data)
# Out:
# 50000

# %%
#one hot encode target
# classes = [[0,1,2,3,4,5,6,7][source] for source in dataSort.ipc_section]
classes = [{"A":0,"B":1,"C":2,"D":3,"E":4,"F":5,"G":6,"H":7}[source] for source in data.ipc_section]
target = to_categorical(classes)
#print target
# target[2002]
len(target)
# Out:
# 50000

# %%
BATCHSIZE = 100

inputs = Input(shape=(512,),dtype=tf.float32,name="InputString")
x = Dense(256,activation="relu")(inputs)
# x = Dense(256,activation="relu",kernel_regularizer=tf.keras.regularizers.L2(0.02))(inputs)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = Dense(8,activation="softmax")(x)

model = keras.Model(inputs=inputs,outputs=outputs,name="modeltest")
model.summary()
model.compile(optimizer="adam", loss="categorical_crossentropy",metrics=["Accuracy"])
# Out:
# Model: "modeltest"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  InputString (InputLayer)    [(None, 512)]             0
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 133,384
# Trainable params: 133,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelhistory = model.fit(
    embed(data.abstract),
    target, 
    epochs=50,
    batch_size=BATCHSIZE, 
    validation_split=0.2
    # validation_data=(data.text[6000:],target[6000:]),
    # callbacks=[EarlyStopping(patience=10)]
)
# Out:
# 2023-02-15 18:40:48.599279: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 1921200000 exceeds 10% of free system memory.
# 2023-02-15 18:40:49.433941: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 1920000000 exceeds 10% of free system memory.
# 2023-02-15 18:40:50.819622: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 1921200000 exceeds 10% of free system memory.
# 2023-02-15 18:40:52.450647: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 1921200000 exceeds 10% of free system memory.
# 2023-02-15 18:40:56.419119: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 3842400000 exceeds 10% of free system memory.
# 2023-02-15 18:41:59.063244: W tensorflow/tsl/framework/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.37GiB (rounded to 17580441600)requested by op StatefulPartitionedCall/StatefulPartitionedCall/EncoderDNN/EmbeddingLookup/EmbeddingLookupUnique/GatherV2
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-02-15 18:41:59.063295: I tensorflow/tsl/framework/bfc_allocator.cc:1034] BFCAllocator dump for GPU_0_bfc
# 2023-02-15 18:41:59.063309: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (256): 	Total Chunks: 19, Chunks in use: 19. 4.8KiB allocated for chunks. 4.8KiB in use in bin. 140B client-requested in use in bin.
# 2023-02-15 18:41:59.063317: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-15 18:41:59.063324: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1024): 	Total Chunks: 2, Chunks in use: 2. 2.2KiB allocated for chunks. 2.2KiB in use in bin. 2.0KiB client-requested in use in bin.
# 2023-02-15 18:41:59.063331: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-15 18:41:59.063338: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-15 18:41:59.063346: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8192): 	Total Chunks: 62, Chunks in use: 61. 821.5KiB allocated for chunks. 808.0KiB in use in bin. 808.0KiB client-requested in use in bin.
# 2023-02-15 18:41:59.063353: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16384): 	Total Chunks: 60, Chunks in use: 60. 1.25MiB allocated for chunks. 1.25MiB in use in bin. 1.25MiB client-requested in use in bin.
# 2023-02-15 18:41:59.063360: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (32768): 	Total Chunks: 30, Chunks in use: 30. 1.00MiB allocated for chunks. 1.00MiB in use in bin. 1.00MiB client-requested in use in bin.
# 2023-02-15 18:41:59.063366: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-15 18:41:59.063383: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (131072): 	Total Chunks: 1, Chunks in use: 1. 195.5KiB allocated for chunks. 195.5KiB in use in bin. 195.3KiB client-requested in use in bin.
# 2023-02-15 18:41:59.063390: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (262144): 	Total Chunks: 3, Chunks in use: 2. 1.16MiB allocated for chunks. 800.0KiB in use in bin. 800.0KiB client-requested in use in bin.
# 2023-02-15 18:41:59.063397: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (524288): 	Total Chunks: 3, Chunks in use: 3. 2.10MiB allocated for chunks. 2.10MiB in use in bin. 1.75MiB client-requested in use in bin.
# 2023-02-15 18:41:59.063404: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1048576): 	Total Chunks: 1, Chunks in use: 1. 1.00MiB allocated for chunks. 1.00MiB in use in bin. 1.00MiB client-requested in use in bin.
# 2023-02-15 18:41:59.063411: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-15 18:41:59.063417: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-15 18:41:59.063423: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-15 18:41:59.063429: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-15 18:41:59.063440: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (33554432): 	Total Chunks: 32, Chunks in use: 32. 1.06GiB allocated for chunks. 1.06GiB in use in bin. 1.06GiB client-requested in use in bin.
# 2023-02-15 18:41:59.063447: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-15 18:41:59.063454: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (134217728): 	Total Chunks: 2, Chunks in use: 0. 361.69MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-15 18:41:59.063462: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (268435456): 	Total Chunks: 2, Chunks in use: 1. 11.24GiB allocated for chunks. 567.07MiB in use in bin. 567.07MiB client-requested in use in bin.
# 2023-02-15 18:41:59.063469: I tensorflow/tsl/framework/bfc_allocator.cc:1057] Bin for 16.37GiB was 256.00MiB, Chunk State:
# 2023-02-15 18:41:59.063483: I tensorflow/tsl/framework/bfc_allocator.cc:1063]   Size: 10.69GiB | Requested Size: 60.5KiB | in_use: 0 | bin_num: 20, prev:   Size: 567.07MiB | Requested Size: 567.07MiB | in_use: 1 | bin_num: -1
# 2023-02-15 18:41:59.063488: I tensorflow/tsl/framework/bfc_allocator.cc:1070] Next region of size 13593214976
# 2023-02-15 18:41:59.063497: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f8
I tensorflow/tsl/framework/bfc_allocator.cc:1098] 40 Chunks of size 22528 totalling 880.0KiB
# 2023-02-15 18:41:59.065744: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 28 Chunks of size 34816 totalling 952.0KiB
# 2023-02-15 18:41:59.065754: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 2 Chunks of size 36864 totalling 72.0KiB
# 2023-02-15 18:41:59.065765: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 200192 totalling 195.5KiB
# 2023-02-15 18:41:59.065775: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 2 Chunks of size 409600 totalling 800.0KiB
# 2023-02-15 18:41:59.065784: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 524288 totalling 512.0KiB
# 2023-02-15 18:41:59.065794: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 655360 totalling 640.0KiB
# 2023-02-15 18:41:59.065805: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1022208 totalling 998.2KiB
# 2023-02-15 18:41:59.065816: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1048576 totalling 1.00MiB
# 2023-02-15 18:41:59.065827: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 30 Chunks of size 34133760 totalling 976.57MiB
# 2023-02-15 18:41:59.065838: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 2 Chunks of size 54938880 totalling 104.79MiB
# 2023-02-15 18:41:59.065849: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 594613760 totalling 567.07MiB
# 2023-02-15 18:41:59.065865: I tensorflow/tsl/framework/bfc_allocator.cc:1102] Sum Total of in-use chunks: 1.62GiB
# 2023-02-15 18:41:59.065878: I tensorflow/tsl/framework/bfc_allocator.cc:1104] total_region_allocated_bytes_: 13593214976 memory_limit_: 13593214976 available bytes: 0 curr_region_allocation_bytes_: 27186429952
# 2023-02-15 18:41:59.065895: I tensorflow/tsl/framework/bfc_allocator.cc:1110] Stats:
# Limit:                     13593214976
# InUse:                      1735968000
# MaxInUse:                   2526665728
# NumAllocs:                         389
# MaxAllocSize:               1280400128
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-02-15 18:41:59.065945: W tensorflow/tsl/framework/bfc_allocator.cc:492] ********_*******____________________________________________________________________________________
# 2023-02-15 18:41:59.065990: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at gather_op.cc:158 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[13734720,320] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_15051/3194043735.py in <module>
#       1 modelhistory = model.fit(
# ----> 2     embed(data.abstract),
#       3     target,
#       4     epochs=50,
#       5     batch_size=BATCHSIZE,
#
# /opt/conda/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_hub/keras_layer.py in call(self, inputs, training)
#     227     # or else Keras' global `learning_phase`, which might actually be a tensor.
#     228     if not self._has_training_argument:
# --> 229       result = f()
#     230     else:
#     231       if self.trainable:
#
# ResourceExhaustedError: Exception encountered when calling layer 'keras_layer' (type KerasLayer).
#
# Graph execution error:
#
# OOM when allocating tensor with shape[13734720,320] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node EncoderDNN/EmbeddingLookup/EmbeddingLookupUnique/GatherV2}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_restored_function_body_4648]
#
# Call arguments received by layer 'keras_layer' (type KerasLayer):
#   • inputs=85814    Disclosed is a photosensitive resin compositio...
# 73954    To provide a superconductor of extremely high ...
# 49155    The invention relates to a power source and hy...
# 59522    Systems, devices, and methods for dosimetric v...
# 3479     A receiver circuit for an optical communicatio...
#                                ...
# 64188    Methods and systems are provided for operating...
# 90890    The utility model provides a quayside containe...
# 48758    PURPOSE: An aircell and an air cushion using t...
# 40766    Disclosed are hair conditioning compositions, ...
# 61072    In accordance with an example embodiment of th...
# Name: abstract, Length: 50000, dtype: object
#   • training=None

# %%
pd.DataFrame(modelhistory.history)[["loss","val_loss"]].plot(title="BS="+ str(BATCHSIZE) +" | USE | 256 dense")
pd.DataFrame(modelhistory.history)[["Accuracy","val_Accuracy"]].plot(title="BS="+ str(BATCHSIZE) +" | USE | 256 dense")
