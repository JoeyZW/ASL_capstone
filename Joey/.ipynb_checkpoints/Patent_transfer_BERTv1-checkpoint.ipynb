# %%
import os
import shutil

import pandas as pd
import tensorflow as tf
import numpy as np
import tensorflow_hub as hub
import tensorflow_text as text
import keras

from keras import Input
from keras.layers import TextVectorization
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import (
    GRU,
    Conv1D,
    Dense,
    Embedding,
    Flatten,
    Lambda,
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical

print(tf.__version__)
# Out:
# 2023-02-15 18:51:00.980709: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-15 18:51:02.405346: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2023-02-15 18:51:02.405505: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2023-02-15 18:51:02.405522: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2.11.0

# %%
bert_model = hub.KerasLayer("https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-512_A-8/2")
# preprocess = hub.load("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# 2023-02-15 18:51:06.191442: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:51:06.205426: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:51:06.207282: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:51:06.209868: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-15 18:51:06.210853: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:51:06.212752: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:51:06.214512: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:51:06.987495: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:51:06.989594: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:51:06.991482: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-15 18:51:06.993211: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13582 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %%
bert_preprocess_model = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
# preprocess = hub.load

# %%
#read data
data = pd.read_csv("../data/patent_rand100k.csv")
#shuffle data
# data = data.sample(frac=1)

# %%
# # data.groupby('ipc_section').count()
# dataSort = data.query('(ipc_section == "A")').sample(n=1000)
# dataSort = pd.concat([dataSort,data.query('(ipc_section == "B")').sample(n=1000)])
# dataSort = pd.concat([dataSort,data.query('(ipc_section == "C")').sample(n=1000)])
# dataSort = pd.concat([dataSort,data.query('(ipc_section == "D")').sample(n=1000)])
# dataSort = pd.concat([dataSort,data.query('(ipc_section == "E")').sample(n=1000)])
# dataSort = pd.concat([dataSort,data.query('(ipc_section == "F")').sample(n=1000)])
# dataSort = pd.concat([dataSort,data.query('(ipc_section == "G")').sample(n=1000)])
# dataSort = pd.concat([dataSort,data.query('(ipc_section == "H")').sample(n=1000)])

# dataSort

# %%
#one hot encode target
# classes = [[0,1,2,3,4,5,6,7][source] for source in dataSort.ipc_section]
classes = [{"A":0,"B":1,"C":2,"D":3,"E":4,"F":5,"G":6,"H":7}[source] for source in data.ipc_section]
target = to_categorical(classes)
#print target
# target[2002]

# %%
BATCHSIZE = 50

inputs = Input(shape=(),dtype=tf.string,name="InputString")
x = bert_model(bert_preprocess_model(inputs))
x = Dense(256,activation="relu",kernel_regularizer=tf.keras.regularizers.L2(0.01))(x["pooled_output"])
x = tf.keras.layers.Dropout(0.2)(x)
# x = GRU(16)(inputs)
# x = inputs
outputs = Dense(8,activation="softmax")(x)

model = keras.Model(inputs=inputs,outputs=outputs,name="modeltest")
model.summary()
model.compile(optimizer="adam", loss="categorical_crossentropy",metrics=["Accuracy"])
# Out:
# Model: "modeltest"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  InputString (InputLayer)       [(None,)]            0           []
#
#  keras_layer_1 (KerasLayer)     {'input_word_ids':   0           ['InputString[0][0]']
#                                 (None, 128),
#                                  'input_type_ids':
#                                 (None, 128),
#                                  'input_mask': (Non
#                                 e, 128)}
#
#  keras_layer (KerasLayer)       {'sequence_output':  28763649    ['keras_layer_1[1][0]',
#                                  (None, 128, 512),                'keras_layer_1[1][1]',
#                                  'default': (None,                'keras_layer_1[1][2]']
#                                 512),
#                                  'pooled_output': (
#                                 None, 512),
#                                  'encoder_outputs':
#                                  [(None, 128, 512),
#                                  (None, 128, 512),
#                                  (None, 128, 512),
#                                  (None, 128, 512)]}
#
#  dense_1 (Dense)                (None, 256)          131328      ['keras_layer[1][5]']
#
#  dropout (Dropout)              (None, 256)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 8)            2056        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 28,897,033
# Trainable params: 133,384
# Non-trainable params: 28,763,649
# __________________________________________________________________________________________________

# %%
data.abstract[80000:]
# Out:
# 80000    The invention discloses a flexible moisture-ab...
# 80001    The utility model relates to lightgage steel j...
# 80002    To provide a cryopreservation container capabl...
# 80003    The present invention relates to the method th...
# 80004    The utility model discloses a kind of storing ...
#                                ...
# 99995    The invention relates to an automatic foreign ...
# 99996    An integrated proteomics sample preparation de...
# 99997    Computer-accessible medium and apparatus for p...
# 99998    The utility model discloses a kind of solar de...
# 99999    The utility model relates to a quality inspect...
# Name: abstract, Length: 20000, dtype: object

# %%
modelhistory = model.fit(
    data.abstract[:8000],
    target[:8000], 
    epochs=50,
    batch_size=BATCHSIZE, 
    # validation_split=0.2
    validation_data=(data.abstract[8000:10000],target[8000:10000]),
    # callbacks=[EarlyStopping(patience=10)]
)
# Out:
# Epoch 1/50
# 160/160 [==============================] -
50
# 160/160 [==============================] - 36s 224ms/step - loss: 1.3929 - Accuracy: 0.5030 - val_loss: 1.3923 - val_Accuracy: 0.5065
# Epoch 28/50
# 160/160 [==============================] - 37s 233ms/step - loss: 1.3876 - Accuracy: 0.5044 - val_loss: 1.4037 - val_Accuracy: 0.4860
# Epoch 29/50
# 160/160 [==============================] - 36s 224ms/step - loss: 1.4048 - Accuracy: 0.4936 - val_loss: 1.3912 - val_Accuracy: 0.5035
# Epoch 30/50
# 160/160 [==============================] - 37s 233ms/step - loss: 1.3857 - Accuracy: 0.5098 - val_loss: 1.3718 - val_Accuracy: 0.5080
# Epoch 31/50
# 160/160 [==============================] - 37s 234ms/step - loss: 1.3909 - Accuracy: 0.5034 - val_loss: 1.4023 - val_Accuracy: 0.5000
# Epoch 32/50
# 160/160 [==============================] - 36s 224ms/step - loss: 1.3850 - Accuracy: 0.5010 - val_loss: 1.3978 - val_Accuracy: 0.5030
# Epoch 33/50
# 160/160 [==============================] - 37s 234ms/step - loss: 1.3947 - Accuracy: 0.4992 - val_loss: 1.3872 - val_Accuracy: 0.5025
# Epoch 34/50
# 160/160 [==============================] - 39s 244ms/step - loss: 1.3906 - Accuracy: 0.5013 - val_loss: 1.4356 - val_Accuracy: 0.4775
# Epoch 35/50
# 160/160 [==============================] - 36s 224ms/step - loss: 1.3846 - Accuracy: 0.5020 - val_loss: 1.3853 - val_Accuracy: 0.5080
# Epoch 36/50
# 160/160 [==============================] - 37s 233ms/step - loss: 1.3999 - Accuracy: 0.5002 - val_loss: 1.4105 - val_Accuracy: 0.4935
# Epoch 37/50
# 160/160 [==============================] - 36s 224ms/step - loss: 1.3883 - Accuracy: 0.5040 - val_loss: 1.3787 - val_Accuracy: 0.5005
# Epoch 38/50
# 160/160 [==============================] - 37s 233ms/step - loss: 1.3857 - Accuracy: 0.5056 - val_loss: 1.3853 - val_Accuracy: 0.5195
# Epoch 39/50
# 160/160 [==============================] - 37s 234ms/step - loss: 1.3952 - Accuracy: 0.4933 - val_loss: 1.3885 - val_Accuracy: 0.5070
# Epoch 40/50
# 160/160 [==============================] - 36s 223ms/step - loss: 1.3714 - Accuracy: 0.5001 - val_loss: 1.4021 - val_Accuracy: 0.5170
# Epoch 41/50
# 160/160 [==============================] - 37s 232ms/step - loss: 1.3715 - Accuracy: 0.5080 - val_loss: 1.3850 - val_Accuracy: 0.5085
# Epoch 42/50
# 160/160 [==============================] - 36s 223ms/step - loss: 1.3776 - Accuracy: 0.5114 - val_loss: 1.3886 - val_Accuracy: 0.5090
# Epoch 43/50
# 160/160 [==============================] - 37s 235ms/step - loss: 1.3796 - Accuracy: 0.5067 - val_loss: 1.4004 - val_Accuracy: 0.4940
# Epoch 44/50
# 160/160 [==============================] - 37s 233ms/step - loss: 1.3824 - Accuracy: 0.5051 - val_loss: 1.3729 - val_Accuracy: 0.5065
# Epoch 45/50
# 160/160 [==============================] - 36s 223ms/step - loss: 1.3672 - Accuracy: 0.5094 - val_loss: 1.3775 - val_Accuracy: 0.5035
# Epoch 46/50
# 160/160 [==============================] - 37s 234ms/step - loss: 1.3858 - Accuracy: 0.5071 - val_loss: 1.4961 - val_Accuracy: 0.4480
# Epoch 47/50
# 160/160 [==============================] - 36s 223ms/step - loss: 1.3905 - Accuracy: 0.5090 - val_loss: 1.3618 - val_Accuracy: 0.5170
# Epoch 48/50
# 160/160 [==============================] - 37s 233ms/step - loss: 1.3889 - Accuracy: 0.4996 - val_loss: 1.3830 - val_Accuracy: 0.4970
# Epoch 49/50
# 160/160 [==============================] - 37s 233ms/step - loss: 1.3774 - Accuracy: 0.5031 - val_loss: 1.3761 - val_Accuracy: 0.5105
# Epoch 50/50
# 160/160 [==============================] - 36s 223ms/step - loss: 1.3776 - Accuracy: 0.5059 - val_loss: 1.3777 - val_Accuracy: 0.5235

# %%
pd.DataFrame(modelhistory.history)[["loss","val_loss"]].plot(title="BS="+ str(BATCHSIZE) +" | USE | 256 dense")
pd.DataFrame(modelhistory.history)[["Accuracy","val_Accuracy"]].plot(title="BS="+ str(BATCHSIZE) +" | USE | 256 dense")
# Out:
# <AxesSubplot:title={'center':'BS=50 | USE | 256 dense'}>
